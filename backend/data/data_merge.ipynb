# %%
import pandas as pd
aesop = pd.read_csv('Aesop.csv')
word_info = pd.read_csv('word_info.csv')
display(aesop, word_info)
# Out:
#       id                                title  \
# 0      0               THE FOX AND THE GRAPES
# 1      1  THE GOOSE THAT LAID THE GOLDEN EGGS
# 2      2                 THE CAT AND THE MICE
# 3      3                  THE MISCHIEVOUS DOG
# 4      4   THE CHARCOAL-BURNER AND THE FULLER
# ..   ...                                  ...
# 279  279             THE SWALLOW AND THE CROW
# 280  280          THE HUNTER AND THE HORSEMAN
# 281  281      THE GOATHERD AND THE WILD GOATS
# 282  282      THE NIGHTINGALE AND THE SWALLOW
# 283  283            THE TRAVELLER AND FORTUNE
#
#                                                episode
# 0    A hungry Fox saw some fine bunches of Grapes h...
# 1    A Man and his Wife had the good fortune to pos...
# 2    There was once a house that was overrun with M...
# 3    There was once a Dog who used to snap at peopl...
# 4    There was once a Charcoal-burner who lived and...
# ..                                                 ...
# ...

# %%
output = pd.merge(word_info, aesop, how='left', on='title')
display((output))
output.to_csv('word_info_episode.csv')
# Out:
#                            title  doc_len     word  pos  sent_id      tf  \
# 0         THE FOX AND THE GRAPES        3   hungry    3        1  0.0625
# 1         THE FOX AND THE GRAPES        3      fox    1        1  0.0625
# 2         THE FOX AND THE GRAPES        3      see    2        1  0.0625
# 3         THE FOX AND THE GRAPES        3     fine    3        1  0.0625
# 4         THE FOX AND THE GRAPES        3    bunch    1        1  0.0625
# ...                          ...      ...      ...  ...      ...     ...
# 13116  THE TRAVELLER AND FORTUNE        4     fall    2        4  0.2000
# 13117  THE TRAVELLER AND FORTUNE        4     well    1        4  0.2000
# 13118  THE TRAVELLER AND FORTUNE        4    blame    1        4  0.2000
# 13119  THE TRAVELLER AND FORTUNE        4    throw    2        4  0.2000
# 13120  THE TRAVELLER AND FORTUNE        4  fortune    1        4  0.2000
#
#             idf    tf_idf   id  \
# 0      1.098612  0.068663    0
# ...
